# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# plt.xkcd()


# eventually make this a text file
vege_dict = {
             202033:
                ['yellow onion','garlic','red onion','zucchini','yellow squash','black beans','red bell pepper','carrots',
                 'spinach'],
             202034:
                ['sweet potato','broccoli','spinach','baby bella mushrooms','zucchini','red bell pepper','cabbage',
                 'edamame','shiitake mushrooms','carrots','yellow onion','black beans','garlic'],
             202035:
                ['yellow onion','red onion','black olives','kale','spinach','baby bella mushrooms','zucchini',
                 'tomato','cucumber','yellow squash','carrots','cabbage'],
             202036:
                ['zucchini','yellow squash','chickpeas','yellow onion','red onion','black olives','kale','carrots',
                 'romaine lettuce','avocado','red bell pepper','baby bella mushrooms'],
             202037:
                ['yellow onion','carrots','white onion','butternut squash','scallion','cauliflower','chickpeas',
                 'black olives','spinach','red bell pepper','garlic','zucchini','water chestnuts','baby bella mushrooms',
                 'apple'],
             202038:
                ['red bell pepper','yellow onion','garlic','red onion','yellow squash','cabbage','tomato',
                 'baby bella mushrooms','edamame','other leaf greens'],
             202039:
                ['kale','carrots','tomato','celery','zucchini','yellow onion','cannellini beans','garlic','eggplant'],
             202040:
                ['chickpeas','yellow onion','red bell pepper','green lentils'],
             202041:
                ['yellow onion','peas','red onion','garlic','red bell pepper','tomato','green beans','black beans'],
             202042: 
                ['yellow squash','yellow onion','jalapeno pepper','poblano pepper','shiitake mushrooms','black beans',
                 'black olives','hominy','radish','lime','sweet potato','ginger','garlic','scallion','chickpeas',
                 'other leaf greens','avocado','red bell pepper','tomato','kale','cucumber'],
             202043:
                ['kale','baby bella mushrooms','shallot','yellow onion','eggplant','tomato','green beans','water chestnuts',
                 'spinach','red onion','black olives','red bell pepper','garlic','ginger','carrots'],
             202044:
                ['tomatillo','garlic','jalapeno pepper','yellow onion','shiitake mushrooms','baby bok choy','shallot','jackfruit','pineapple',
                 'baby bella mushrooms','sweet potato','carrots','ginger','other mushrooms','avocado'],
             202045:
                ['white mushrooms','shiitake mushrooms','shallot','yellow onion','tomato','green beans', 'spinach','red onion','red bell pepper',
                 'garlic','cannellini beans','basil','eggplant','broccoli','scallions','celery'],
             202046:
                ['white mushrooms','shallot','yellow onion','tomato','asparagus', 'spinach','red onion','red bell pepper',
                 'garlic','zucchini','yellow squash','butternut squash','great northern beans','basil','black beans']
            }

# %%
# eventually load vegedict from text file

# iterate over vegedict to create: dict of occurences
counts_dict = {}
for veglist in vege_dict.values():
    for veg in veglist:
        if veg not in counts_dict:
            counts_dict[veg] = 1
        else:
            counts_dict[veg] += 1
            
# save the dict to a file

# each time run, append new data to file

# %%
counts_list = []
for item in counts_dict.items():
    counts_list.append(item)

counts_list.sort(key=lambda x: x[0])

# %%
# for elem in counts_list:
#     print(elem)
vegs = [x[0] for x in counts_list]
counts = [x[1] for x in counts_list]

# %%
fig,ax = plt.subplots(figsize=(18,6))

ax.bar([2*x for x in range(len(counts))],counts,tick_label=vegs,color='orange',width=1)
ax.set_title("Running vegetable consumption in Fortman-Huft household",fontsize=18)
ax.set_ylabel('Number of weeks vegetable used',fontsize=12)
plt.xticks(rotation=80)
plt.show()
